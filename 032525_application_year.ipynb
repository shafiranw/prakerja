# %% [markdown]
# # Assign Application Year for Non-Applicants
# Using distribution of applicants, I randomly assign year of application for non-applicants

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (11, 5)  #set default figure size
import numpy as np
from numpy import exp
from scipy.special import factorial
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
from statsmodels.api import Poisson
from scipy.stats import norm
from statsmodels.iolib.summary2 import summary_col

# %%
# Load Datasets
sakernas = pd.read_csv('/Users/shafiranw/Documents/PhD/Dissertation/code_data/data/032425_sakernas_wagesim.csv')
sakernas.head()
# Out:
#    id  age  age2  male  married  educ  hhsize  village  disability  employ  \
# 0   1   65  4225     0        1     6       2        0           0       0
# 1   2   65  4225     0        1     6       2        0           0       0
# 2   3   31   961     1        0    12       2        0           0       1
# 3   4   28   784     1        0    16       2        0           0       1
# 4   5   40  1600     1        1    12       2        0           0       1
#
#    ...  pk_inc_capital  pk_inc_debt  pk_inc_transport  pk_inc_internet  \
# 0  ...             NaN          NaN               NaN              NaN
# 1  ...             NaN          NaN               NaN              NaN
# 2  ...             NaN          NaN               NaN              NaN
# 3  ...             NaN          NaN               NaN              NaN
# 4  ...             NaN          NaN               NaN              NaN
#
#    pk_inc_train  pk_inc_other  age_before  age2_before  ln_wage_before  \
# ...

# %%
# Count distribution of applicants by year
accept_year_counts = sakernas["pk_accept_year"].value_counts(normalize=True).sort_index()
print(accept_year_counts)
# Out:
# pk_accept_year
# 1.0    0.380139
# 2.0    0.361099
# 3.0    0.224784
# 4.0    0.033978
# Name: proportion, dtype: float64

# %%
# Assign hypothetical application year to non-applicants
sakernas.loc[sakernas["pk_apply"]==0, "hyp_pk_app_year"] = np.random.choice(
    accept_year_counts.index, size=(sakernas["pk_apply"]==0).sum(), p=accept_year_counts.values
)
print(sakernas.head(30))
# Out:
#     id  age  age2  male  married  educ  hhsize  village  disability  employ  \
# 0    1   65  4225     0        1     6       2        0           0       0
# 1    2   65  4225     0        1     6       2        0           0       0
# 2    3   31   961     1        0    12       2        0           0       1
# 3    4   28   784     1        0    16       2        0           0       1
# 4    5   40  1600     1        1    12       2        0           0       1
# 5    6   40  1600     0        1     6       2        0           0       0
# 6    7   35  1225     1        1    12       3        0           0       1
# 7    8   30   900     0        1     9       3        0           0       0
# 8    9   48  2304     1        1     9       3        0           0       1
# 9   10   35  1225     0        1     6       3        0           0       0
# 10  11   59  3481     1        1     9       3        0           0       1
# ...

# %%
# Save dataset
sakernas.to_csv('032525_sakernas_hyp_app_year.csv', index=False)
